# %%
import pandas as pd
import numpy as np 

max([-1,-3])

# %%
ans

# %%
from urllib.request import urlopen
import re
import urllib
from http.cookiejar import CookieJar
cj = CookieJar()
opener = urllib.request.build_opener(urllib.request.HTTPCookieProcessor(cj))

# %%
sourcecode = opener.open(google_news_url).read().decode('utf-8')

# %%
import re
regex = '(?=<title>)(.*?)(?=</title>)'
regexp = re.compile(regex)

# %%
sourcecode[:1400]

# %%
ans = re.findall(regexp,sourcecode)

# %%
ans[2]

# %%
bytes([1,2,3,4])

# %%
type(sourcecode)

# %%
def get_payments_storage():
    """
    @returns an instance of
    https://docs.python.org/3/library/io.html#io.BufferedWriter
    """
    # Sample implementation to make the code run in coderpad.
    # Do not rely on this exact implementation.
    return open('temp.txt', 'wb')

# %%
def process_payments(chunksize=None):
    """
    TODO:
    Modify `process_payments()` to print the checksum of data
    generated by the `stream_payments_to_storage()` call.
    """
    """Added chunksize parameter to control amount of data
       stored into file"""
    import numpy as np
    storage = get_payments_storage()
    # Writing to a buffer
    import io
    output = io.BytesIO()
    # store the data in memory
    # using function once
    stream_payments_to_storage(output)
    buffer = output.getbuffer()
    return buffer.shape[0]

# %%
# This is a library function, you can't modify it.
def stream_payments_to_storage(storage):
    """
    Loads payments and writes them to the `storage`.
    Returns when all payments have been written.

    @parameter `storage`: is an instance of
    https://docs.python.org/3/library/io.html#io.BufferedWriter
    """
    # Sample implementation to make the code run in coderpad.
    # Do not rely on this exact implementation.
    for i in range(100):
        storage.write(bytes([1,2,3,4,5]))

# %%
buffer = process_payments()

# %%
buffer

# %%
storage = get_payments_storage()

# %%
import io
output = io.BytesIO()
stream_payments_to_storage(output)
buffer = output.getbuffer()

# %%
sum(buffer)

# %%
n = len(output.getvalue())
for c in range(0,n,chunksize):
    chunk = c*chunksize
   data = output.getvalue()[chunk:chunk+chunksize]
   storage.write(data)

# %%
output.getvalue()[0:0+chunksize]

# %%
output.getvalue()[4:4+chunksize]

# %%
output.getvalue()[8:8+chunksize]

# %%
import io


# This is a library function, you can't modify it.
def stream_payments(callback_fn):
    """
    Reads payments from a payment processor and calls `callback_fn(amount)`
    for each payment. 
    
    Returns when there is no more payments.
    """
    # Sample implementation to make the code run in coderpad.
    # Do not rely on this exact implementation.
    for i in range(10):
        callback_fn(i)


# This is a library function, you can't modify it.
def store_payments(amount_iterator):
    """
    Iterates over the payment amounts from amount_iterator 
    and stores them to a remote system.
    """
    # Sample implementation to make the code run in coderpad.
    # Do not rely on this exact implementation.
    for i in amount_iterator:
        print(i)


def callback_example(amount):
    print(amount)
    return True


def process_payments_2():
    """
    TODO: 
    Modify `process_payments_2()`, write glue code that enables
    `store_payments()` to consume payments produced by `stream_payments()`
    """
    def wrapper():
        
        import io
        from contextlib import redirect_stdout
        # redirect output from stream payments to output
        with io.StringIO() as buf, redirect_stdout(buf):
            stream_payments(callback_example)
            output = buf.getvalue()
        yield output
    output = wrapper()
    store_payments(output)

# %%
google_news_url="https://news.google.com/news/rss"


def get_headlines(rss_url):
    """
    @returns a list of titles from the rss feed located at `rss_url`    
    """
    from urllib.request import urlopen
    import re 
    import urllib 
    from http.cookiejar import CookieJar
    cj = CookieJar()
    opener = urllib.request.build_opener(urllib.request.HTTPCookieProcessor(cj))
    sourcecode = opener.open(rss_url).read().decode('utf-8')
    regex = '(?=<title>)(.*?)(?=</title>)'
    regexp = re.compile(regex)
    ans = re.findall(regexp,sourcecode)
    return ans 
    

ans = get_headlines(google_news_url)

# %%
ans
# Out:
# ['<title>Top stories - Google News',
#  '<title>Trump’s Deference to Saudis in Setting Terms for How U.S. Should Respond to Attacks Touches a Nerve - The New York Times',
#  "<title>New York Times' botched Kavanaugh story the latest in series of blunders from Opinion section - CNN",
#  "<title>Eugene Robinson: Trump administration is more 'Game of Thrones' than 'West Wing' - Salt Lake Tribune",
#  "<title>Eight years of Trump's tax returns subpoenaed by Manhattan District Attorney Cyrus Vance Jr. - CNBC",
#  '<title>Maine Senate race: Kavanaugh is looming over Susan Collins’s 2020 reelection - Vox.com',
#  '<title>Forecasters warn of US coast rip currents caused by Humberto - WJHG-TV',
#  '<title>Huge explosion in Farmington destroys building - WGME',
#  "<title>'A serial killer off the streets': Florida man charged in woman's death linked to slayings of three others - USA TODAY",
#  '<title>Elizabeth Warren at New York City rally: “Corruption is breaking our democracy” - Vox.com',
#  "<title>'We got your back': New Women's March leadership defended ousted members - Washington Examiner",
#  '<title>Brexit: Boris Johnson pulls out of news conference - BBC News - BBC News',
#  '<title>Activist Joshua Wong brings Hong Kong fight to U.S. with upcoming congressional testimony - NBCNews.com',
#  '<title>Explainer: U.S. enacts sweeping new asylum bar following Supreme Court decision - Reuters',
#  '<title>ISIS leader calls for ‘caliphate soldiers’ to free detainees from camps, continue attacks - Fox News',
#  '<title>Tense GM strike talks continue into evening on first day of picketing; health care a key - USA TODAY',
#  '<title>The We Company reportedly will put its public offering on hold - TechCrunch',
#  '<title>General Mills Recalls Gold Medal Flour - Fox Business',
#  '<title>Drone Wars: China Has $400 Billion At Stake In Iran Oil - Forbes',
#  "<title>Apple Arcade Is One Big, Beautiful Trap - Tom's Guide",
#  '<title>Huawei Mate 30 Pro Leak Shows Stunning Design And Cool Features - Forbes',
#  '<title>See how an AI system classifies you based on your selfie - The Verge',
#  "<title>Leaked Slide Shows Google to Add Stadia Support, Launch 'Hero Device' for Android TV in 2020 - Gizmodo",
#  '<title>Netflix Buys Worldwide Rights to “Seinfeld” Beginning in 2021 After Losing “The Office,” “Friends” - Showbiz411',
#  "<title>Kevin Hart's Sex Tape Accuser Called Him a Victim and Promised Not to Sue - TMZ",
#  "<title>Duane 'Dog the Bounty Hunter' Chapman hospitalized nearly 3 months after wife Beth's death - Entertainment Weekly News",
#  "<title>BLACKPINK's Jisoo Attends Burberry Spring 2020 - Papermag",
#  '<title>Dolphins trade Minkah Fitzpatrick to Steelers for 2020 first-round pick, Pittsburgh wants to contend? - CBS Sports',
#  '<title>Fantasy Football Week 3 Early Waiver Wire: Drew Brees, James Conner replacements - CBS Sports',
#  '<title>Colin Kapernick Nabs Emmy For Controversial Nike Ad - The Root',
#  '<title>Milwaukee Brewers break franchise record for home runs in a season with number 232 - Brew Crew Ball',
#  '<title>Astronomers Detect Massive Neutron Star That Is Almost Too Massive to Exist [Video] - SciTechDaily',
#  "<title>Image reveals 2nd interstellar object's cometlike tail - Business Insider",
#  '<title>NASA cubesat to test lunar Gateway orbit - SpaceNews',
#  '<title>KATRIN cuts the mass estimate for the elusive neutrino in half - Phys.org',
#  '<title>For 1 in 16 US women, first sexual intercourse experience was rape, study says - USA TODAY',
#  '<title>Future - The truth about eating eggs - BBC News',
#  '<title>US officials end visit to DRC Ebola region; cases rise to 3129 - CIDRAP',
#  '<title>2 new cases of vaping-related disease confirmed in Wash. state - KOMO News']

# %%
f = fun()

# %%
f
# Out:
# <generator object fun at 0x113dc2620>

# %%
def find_min_pledge(pledge_list):
    from itertools import count, filterfalse
    
    return next(filterfalse(set(pledge_list).__contains__, count(1)))

assert find_min_pledge([1, 3, 6, 4, 1, 2]) == 5

assert find_min_pledge([1, 2, 3]) == 4

assert find_min_pledge([-1, -3]) == 1

# %%
# Out:
# 1
